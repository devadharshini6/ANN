# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gas=pd.read_csv("/content/gas_turbines.csv")

# %%
gas.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gas.shape
# Out:
# (15039, 11)

# %%
Target = gas['TEY']
gas.drop(labels=['TEY'], axis=1,inplace = True)
gas.insert(0, 'Y', Target)
gas = gas.rename({'Y':'TEY'}, axis = 1)
gas.head()
# Out:
#       TEY      AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP  \
# 0  114.70  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605
# 1  114.72  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598
# 2  114.71  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601
# 3  114.72  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606
# 4  114.72  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEY     15039 non-null  float64
#  1   AT      15039 non-null  float64
#  2   AP      15039 non-null  float64
#  3   AH      15039 non-null  float64
#  4   AFDP    15039 non-null  float64
#  5   GTEP    15039 non-null  float64
#  6   TIT     15039 non-null  float64
#  7   TAT     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gas.describe()
# Out:
#                 TEY            AT           AP            AH          AFDP  \
# count  15039.000000  15039.000000  15039.00000  15039.000000  15039.000000
# mean     134.188464     17.764381   1013.19924     79.124174      4.200294
# std       15.829717      7.574323      6.41076     13.793439      0.760197
# min      100.170000      0.522300    985.85000     30.344000      2.087400
# 25%      127.985000     11.408000   1008.90000     69.750000      3.723900
# 50%      133.780000     18.186000   1012.80000     82.266000      4.186200
# 75%      140.895000     23.862500   1016.90000     90.043500      4.550900
# max      174.610000     34.929000   1034.20000    100.200000      7.610600
#
#                GTEP           TIT           TAT           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean      25.419061   1083.798770    545.396183     12.102353      1.972499
# ...

# %%
gas.isnull().sum()
# Out:
# TEY     0
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
gas.corr()
# Out:
#            TEY        AT        AP        AH      AFDP      GTEP       TIT  \
# TEY   1.000000 -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587
# AT   -0.207495  1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067
# AP    0.146939 -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650
# AH   -0.110272 -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781
# AFDP  0.717995 -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254
# GTEP  0.977042 -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526
# TIT   0.891587  0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000
# TAT  -0.720356  0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320
# CDP   0.988473 -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238
# CO   -0.541751 -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272
# NOX  -0.102631 -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636
#
#            TAT       CDP        CO       NOX
# ...

# %%
corr = gas.corr()
fig, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(corr, cmap='cool', annot=True, fmt=".2f")
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
from inspect import getclasstree
f, axes = plt.subplots(5,2, figsize=(15,20))

sns.regplot(x = 'TEY', y = 'AT', data = gas, ax = axes[0,0], color = 'r', scatter_kws={'alpha':0.5})
axes[0,0].set_xlabel('TEY', fontsize = 12)
axes[0,0].set_ylabel('AT', fontsize=12)
axes[0,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AP', data = gas, ax = axes[0,1], color = 'b',scatter_kws={'alpha':0.5})
axes[0,1].set_xlabel('TEY', fontsize = 12)
axes[0,1].set_ylabel('AP', fontsize=12)
axes[0,1].yaxis.set_label_position("right")
axes[0,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'AH', data = gas, ax = axes[1,0], color = 'r',scatter_kws={'alpha':0.5})
axes[1,0].set_xlabel('TEY', fontsize = 12)
axes[1,0].set_ylabel('AH', fontsize=12)
axes[1,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AFDP', data = gas, ax = axes[1,1], color = 'b',scatter_kws={'alpha':0.5})
axes[1,1].set_xlabel('TEY', fontsize = 12)
axes[1,1].set_ylabel('AFDP', fontsize=12)
axes[1,1].yaxis.set_label_position("right")
axes[1,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'GTEP', data = gas, ax = axes[2,0], color = 'r',scatter_kws={'alpha':0.5})
axes[2,0].set_xlabel('TEY', fontsize = 12)
axes[2,0].set_ylabel('GTEP', fontsize=12)
axes[2,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'TIT', data = gas, ax = axes[2,1], color = 'b',scatter_kws={'alpha':0.5})
axes[2,1].set_xlabel('TEY', fontsize = 12)
axes[2,1].set_ylabel('TIT', fontsize=12)
axes[2,1].yaxis.set_label_position("right")
axes[2,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'TAT', data = gas, ax = axes[3,0], color = 'r',scatter_kws={'alpha':0.5})
axes[3,0].set_xlabel('TEY', fontsize = 12)
axes[3,0].set_ylabel('TAT', fontsize=12)
axes[3,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'CDP', data = gas, ax = axes[3,1], color = 'b',scatter_kws={'alpha':0.5})
axes[3,1].set_xlabel('TEY', fontsize = 12)
axes[3,1].set_ylabel('CDP', fontsize=12)
axes[3,1].yaxis.set_label_position("right")
axes[3,1].yaxis.tick_right()

sns.regplot(x = 'TEY', y = 'CO', data = gas, ax = axes[4,0], color = 'r',scatter_kws={'alpha':0.5})
axes[4,0].set_xlabel('TEY', fontsize = 12)
axes[4,0].set_ylabel('CO', fontsize=12)
axes[4,0].yaxis.set_label_position("right")
axes[4,0].yaxis.tick_left()

sns.regplot(x = 'TEY', y = 'NOX', data = gas, ax = axes[4,1], color = 'b',scatter_kws={'alpha':0.5})
axes[4,1].set_xlabel('TEY', fontsize = 12)
axes[4,1].set_ylabel('NOX', fontsize=12)
axes[4,1].yaxis.set_label_position("right")
axes[4,1].yaxis.tick_right()

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

# %%
X = gas.iloc[:,1:]
y = gas.iloc[:,0]

# %%
def select_features(X_train, y_train, X_test):
    fs = SelectKBest(score_func=mutual_info_regression, k='all')
    fs.fit(X_train, y_train)
    X_train_fs = fs.transform(X_train)
    X_test_fs = fs.transform(X_test)
    return X_train_fs, X_test_fs, fs

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# %%
for i in range(len(fs.scores_)):
    print('Feature %d: %f' % (i, fs.scores_[i]))
fig, ax = plt.subplots(figsize=(15, 8))
plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
plt.show()
# Out:
# Feature 0: 0.402878
# Feature 1: 0.144663
# Feature 2: 0.091149
# Feature 3: 0.656419
# Feature 4: 1.589981
# Feature 5: 1.304067
# Feature 6: 0.911997
# Feature 7: 1.709573
# Feature 8: 0.506594
# Feature 9: 0.303005

# %%
# choosing good score
X = gas.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)

# %%
y = gas.iloc[:,0]

# %% [markdown]
# standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]

# %%
scaled_features=scaler.transform(X)
gas_head=pd.DataFrame(scaled_features,columns=X.columns)
gas_head
# Out:
#            AFDP      GTEP       TIT       TAT       CDP
# 0     -0.921232 -1.379101 -1.488376  0.585240 -1.357331
# 1     -0.921495 -1.363528 -1.482325  0.585240 -1.363676
# 2     -0.944385 -1.351309 -1.476275  0.568715 -1.360957
# 3     -0.946884 -1.348194 -1.464173  0.583969 -1.356424
# 4     -0.924389 -1.354663 -1.458123  0.582698 -1.350985
# ...         ...       ...       ...       ...       ...
# 15034 -0.865850 -1.498657 -2.063184  0.103453 -1.543161
# 15035 -0.913470 -1.438759 -2.268905 -0.276638 -1.513247
# 15036 -0.951488 -1.410967 -2.789257 -1.026650 -1.467922
# 15037 -0.988848 -1.447624 -2.456474 -0.528337 -1.422598
# 15038 -1.016605 -1.464635 -2.051083  0.057689 -1.377273
#
# [15039 rows x 5 columns]

# %% [markdown]
# splitting dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# Back propagation

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(9, input_dim=5, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(5, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(2, kernel_initializer='he_uniform', activation='linear'))

# %% [markdown]
# merge model

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %% [markdown]
# fitting model

# %%
model.fit(x_train,y_train, epochs=100, batch_size=40)
# Out:
# Epoch 1/100
# 264/264 [==============================] - 2s 2ms/step - loss: 1.0433 - mse: 1.0433
# Epoch 2/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 3/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9945 - mse: 0.9945
# Epoch 4/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 5/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9949 - mse: 0.9949
# Epoch 6/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 7/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9939 - mse: 0.9939
# Epoch 8/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 9/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9942 - mse: 0.9942
# Epoch 10/100
# ...

# %%
scores = model.evaluate(x_test, y_test)
print((model.metrics_names[1]))
# Out:
# 141/141 [==============================] - 0s 2ms/step - loss: 1.0174 - mse: 1.0174
# mse

# %% [markdown]
# hyperparamter tuning

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam_v2
from keras.layers import Dropout

# %%
X = gas.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)
y = gas.iloc[:,0]

# %%
X = X.iloc[0:520,:]

# %%
y = y.iloc[0:520]

# %%
scaler.fit(X)
y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]

# %%
scaled_features=scaler.transform(X)
gas_head=pd.DataFrame(scaled_features,columns=X.columns)
gas_head
# Out:
#          AFDP      GTEP       TIT       TAT       CDP
# 0   -1.740644 -1.507118 -2.021531  0.636055 -1.612055
# 1   -1.740967 -1.491666 -2.013962  0.636055 -1.618592
# 2   -1.769083 -1.479542 -2.006393  0.623140 -1.615790
# 3   -1.772153 -1.476452 -1.991255  0.635061 -1.611121
# 4   -1.744522 -1.482870 -1.983686  0.634068 -1.605518
# ..        ...       ...       ...       ...       ...
# 515 -1.192385 -1.169075 -1.567389  0.515852 -1.295485
# 516 -1.400507 -1.380649 -3.800257 -0.983206 -1.633533
# 517 -1.361403 -1.377796 -3.497495 -0.742801 -1.607386
# 518 -1.302263 -1.365910 -3.671583 -0.906713 -1.559760
# 519 -1.233427 -1.354500 -3.769980 -1.014995 -1.524275
#
# [520 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
from sklearn.metrics import mean_squared_error

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 5,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'linear'))
    
    adam=adam_v2.Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['mse'])
    return model
# Creating model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Defining grid search parameters
batch_size = [20,40]
epochs = [50,100]
learning_rate = [0.01,0.1]
dropout_rate = [0.1,0.2]
activation_function = ['relu','linear']
init = ['uniform','normal']
neuron1 = [4,8]
neuron2 = [2,4]
# Make dictionary of the grid search parameters
param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10, scoring='neg_mean_squared_error')
grid_result = grid.fit(x_train, y_train)
#results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# [CV 1/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# <ipython-input-36-8b0b4ec950ea>:13: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# 3/3 [==============================] - 0s 10ms/step
# [CV 1/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.237 total time=   2.9s
# [CV 2/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# ...

# %%
final_model = Sequential()
final_model.add(Dense(4,input_dim = 5,kernel_initializer = 'uniform',activation = 'relu'))
final_model.add(Dropout(0.1))
final_model.add(Dense(2,input_dim = 4,kernel_initializer = 'uniform',activation = 'relu'))
final_model.add(Dropout(0.1))
final_model.add(Dense(1,activation = 'linear'))
    
adam=adam_v2.Adam(learning_rate = 0.01)

# %%
final_model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['mse'])

# %%
final_model.fit(x_train,y_train, epochs=50, batch_size=20)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.9525 - mse: 0.9525
# Epoch 2/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9504 - mse: 0.9504
# Epoch 3/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9507 - mse: 0.9507
# Epoch 4/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.9504 - mse: 0.9504
# Epoch 5/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.9517 - mse: 0.9517
# Epoch 6/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.9515 - mse: 0.9515
# Epoch 7/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.9512 - mse: 0.9512
# Epoch 8/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.9502 - mse: 0.9502
# Epoch 9/50
# 19/19 [==============================] - 0s 4ms/step - loss: 0.9509 - mse: 0.9509
# Epoch 10/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9511 - mse: 0.9511
# Epoch 11/50
# ...

# %%
scores = final_model.evaluate(x_test, y_test)
print((final_model.metrics_names[1]))
# Out:
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1169 - mse: 1.1169
# mse

# %%
accuracy = final_model.evaluate(x_test, y_test)
print('Accuracy: ' %(accuracy*100))
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 1.1169 - mse: 1.1169
# Accuracy:
